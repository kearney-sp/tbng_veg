# %%
import os
import geopandas as gpd

# %%
baseDIR = 'T:/3-GIS/ThunderBasin/Weight_Gain_Project/'

shpPATH1 = 'Reed Ranch/TB_wGain_sampling_full.shp'
shpPATH2 = '2021_Sampling/TB_wGain_sampling_2021.shp'

# %%
gdf_1 = gpd.read_file(os.path.join(baseDIR, shpPATH1))
gdf_2 = gpd.read_file(os.path.join(baseDIR, shpPATH2))

# %%
print('gdf_1 has ' + str(len(gdf_1)) + ' rows. Previewing:\n')
display(gdf_1.head(3))
# Out:
# gdf_1 has 396 rows. Previewing:
#   Allotment Edited      aspect  band comment  desc    elev    filename  \
# 0     Weiss   None  214.988190     1    None  Reed  1434.0  East Weiss
# 1     Weiss   None  136.595886     1    None  Reed  1442.0  East Weiss
# 2     Weiss   None  171.952057     1    None  Reed  1449.0  East Weiss
#
#      link model  ...     n_point  pdog     slope  strats       twi   type  \
# 0  TBGPEA   261  ...  553.263048    No  2.681328       1  4.892034  TRACK
# 1  TBGPEA   261  ...  125.299641    No  1.202933       1  5.458528  TRACK
# 2  TBGPEA   261  ...  126.491106    No  3.599061       1  3.243563  TRACK
#
#             x           y         Plot_ID                        geometry
# 0  487377.781  4788436.63  East_Weiss_Pt1  POINT (487377.781 4788436.630)
# 1  487557.781  4791366.63  East_Weiss_Pt2  POINT (487557.781 4791366.630)
# 2  486997.781  4791086.63  East_Weiss_Pt3  POINT (486997.781 4791086.630)
#
# [3 rows x 21 columns]

# %%
print('gdf_2 has ' + str(len(gdf_2)) + ' rows. Previewing:\n')
display(gdf_2.head(3))
# Out:
# gdf_2 has 764 rows. Previewing:
#   Allotment Edited      aspect  band comment  desc    elev    filename  \
# 0     Weiss   None  214.988190   1.0    None  Reed  1434.0  East Weiss
# 1     Weiss   None  136.595886   1.0    None  Reed  1442.0  East Weiss
# 2     Weiss   None  171.952057   1.0    None  Reed  1449.0  East Weiss
#
#      link model  ...     n_point  pdog     slope  strats       twi   type  \
# 0  TBGPEA   261  ...  553.263048    No  2.681328     1.0  4.892034  TRACK
# 1  TBGPEA   261  ...  125.299641    No  1.202933     1.0  5.458528  TRACK
# 2  TBGPEA   261  ...  126.491106    No  3.599061     1.0  3.243563  TRACK
#
#             x           y         Plot_ID                        geometry
# 0  487377.781  4788436.63  East_Weiss_Pt1  POINT (487377.781 4788436.630)
# 1  487557.781  4791366.63  East_Weiss_Pt2  POINT (487557.781 4791366.630)
# 2  486997.781  4791086.63  East_Weiss_Pt3  POINT (486997.781 4791086.630)
#
# [3 rows x 21 columns]

# %%
gdf_out = gdf_2.append(gdf_1).drop_duplicates()

# %%
print('gdf_out has ' + str(len(gdf_out)) + ' rows.\n')

print('Displaying unique filename values:\n')
display(gdf_out.filename.sort_values().unique())

print('\nDisplaying unique Plot_ID values:\n')
display(gdf_out.Plot_ID.sort_values().unique())
# Out:
# gdf_out has 815 rows.
#
# Displaying unique filename values:
# array(["Bill's Home", "Bill's South", 'Blue Tank', 'Burden Place',
#        'Cameron Place', 'Center Owens', 'East', 'East Dorr',
#        'East Rattlesnake', 'East Weiss', 'Frey (Pino Beans)', 'Frey_NE',
#        'Frey_NW', 'Frey_SE', 'Frey_SW', 'Half Section', 'Hogsback',
#        'Home', 'Meadow', 'Middle Lake Creek', 'Miller Place',
#        'N School Section', 'NoName_Nachtman_360', 'NoName_Nacthman_634',
#        'North Owens', 'Pellatz South', 'Rattlesnake', 'S School Section',
#        'Sawmill', 'Section 4', 'Section 8', 'South Pasture', 'Strips',
#        'Top', 'Upper Rattlesnake', 'West Pasture', 'West Rattlesnake',
#        'West Weiss', None], dtype=object)
# Displaying unique Plot_ID values:
# array(["Bill's_Home_Pt1", "Bill's_Home_Pt2", "Bill's_Home_Pt3",
#        "Bill's_Home_Pt4", "Bill's_Home_Pt5", "Bill's_South_Pt1",
#        "Bill's_South_Pt2", "Bill's_South_Pt3", "Bill's_South_Pt4",
#        "Bill's_South_Pt5", "Bill's_South_Pt6", "Bill's_South_Pt7",
#        "Bill's_South_Pt8", 'Blue_Tank_Pt1', 'Blue_Tank_Pt10',
#        'Blue_Tank_Pt2', 'Blue_Tank_Pt3', 'Blue_Tank_Pt4', 'Blue_Tank_Pt5',
#        'Blue_Tank_Pt6', 'Blue_Tank_Pt7', 'Blue_Tank_Pt8', 'Blue_Tank_Pt9',
#        'Burden_Place_Pt1', 'Burden_Place_Pt2', 'Burden_Place_Pt3',
#        'Burden_Place_Pt4', 'Burden_Place_Pt5', 'Burden_Place_Pt6',
#        'Burden_Place_Pt7', 'Cameron_Place_Pt1', 'Cameron_Place_Pt10',
#        'Cameron_Place_Pt2', 'Cameron_Place_Pt3', 'Cameron_Place_Pt4',
#        'Cameron_Place_Pt5', 'Cameron_Place_Pt6', 'Cameron_Place_Pt7',
#        'Cameron_Place_Pt8', 'Cameron_Place_Pt9', 'Center_Owens_Pt1',
#        'Center_Owens_Pt10', 'Center_Owens_Pt11', 'Center_Owens_Pt12',
#        'Center_Owens_Pt13', 'Center_Owens_Pt14', 'Center_Owens_Pt15',
#        'Center_Owens_Pt2', 'Center_Owens_Pt3', 'Center_Owens_Pt4',
#        'Center_Owens_Pt5', 'Center_Owens_Pt6', 'Center_Owens_Pt7',
#        'Center_Owens_Pt8', 'Center_Owens_Pt9', 'East_Dorr_Pt1',
#        'East_Dorr_Pt10', 'East_Dorr_Pt11', 'East_Dorr_Pt12',
#        'East_Dorr_Pt13', 'East_Dorr_Pt14', 'East_Dorr_Pt15',
#        'East_Dorr_Pt16', 'East_Dorr_Pt17', 'East_Dorr_Pt18',
#        'East_Dorr_Pt19', 'East_Dorr_Pt2', 'East_Dorr_Pt20',
#        'East_Dorr_Pt21', 'East_Dorr_Pt22', 'East_Dorr_Pt23',
#        'East_Dorr_Pt24', 'East_Dorr_Pt25', 'East_Dorr_Pt3',
#        'East_Dorr_Pt4', 'East_Dorr_Pt5', 'East_Dorr_Pt6', 'East_Dorr_Pt7',
#        'East_Dorr_Pt8', 'East_Dorr_Pt9', 'East_Pt1', 'East_Pt10',
#        'East_Pt11', 'East_Pt12', 'East_Pt2', 'East_Pt3', 'East_Pt4',
#        'East_Pt5', 'East_Pt6', 'East_Pt7', 'East_Pt8', 'East_Pt9',
#        'East_Rattlesnake_Pt1', 'East_Rattlesnake_Pt10',
#        'East_Rattlesnake_Pt11', 'East_Rattlesnake_Pt12',
#        'East_Rattlesnake_Pt13', 'East_Rattlesnake_Pt14',
#        'East_Rattlesnake_Pt15', 'East_Rattlesnake_Pt16',
#        'East_Rattlesnake_Pt17', 'East_Rattlesnake_Pt18',
#        'East_Rattlesnake_Pt19', 'East_Rattlesnake_Pt2',
#        'East_Rattlesnake_Pt20', 'East_Rattlesnake_Pt21',
#        'East_Rattlesnake_Pt22', 'East_Rattlesnake_Pt23',
#        'East_Rattlesnake_Pt24', 'East_Rattlesnake_Pt25',
#        'East_Rattlesnake_Pt26', 'East_Rattlesnake_Pt27',
#        'East_Rattlesnake_Pt28', 'East_Rattlesnake_Pt3',
#        'East_Rattlesnake_Pt4', 'East_Rattlesnake_Pt5',
#        'East_Rattlesnake_Pt6', 'East_Rattlesnake_Pt7',
#        'East_Rattlesnake_Pt8', 'East_Rattlesnake_Pt9', 'East_Weiss_Pt1',
#        'East_Weiss_Pt10', 'East_Weiss_Pt11', 'East_Weiss_Pt12',
#        'East_Weiss_Pt13', 'East_Weiss_Pt14', 'East_Weiss_Pt15',
#        'East_Weiss_Pt16', 'East_Weiss_Pt17', 'East_Weiss_Pt18',
#        'East_Weiss_Pt19', 'East_Weiss_Pt2', 'East_Weiss_Pt20',
#        'East_Weiss_Pt21', 'East_Weiss_Pt22', 'East_Weiss_Pt23',
#        'East_Weiss_Pt24', 'East_Weiss_Pt25', 'East_Weiss_Pt26',
#        'East_Weiss_Pt27', 'East_Weiss_Pt28', 'East_Weiss_Pt29',
#        'East_Weiss_Pt3', 'East_Weiss_Pt30', 'East_Weiss_Pt4',
#        'East_Weiss_Pt5', 'East_Weiss_Pt6', 'East_Weiss_Pt7',
#        'East_Weiss_Pt8', 'East_Weiss_Pt9', 'Frey_(Pino_Beans)_Pt1',
#        'Frey_(Pino_Beans)_Pt10', 'Frey_(Pino_Beans)_Pt2',
#        'Frey_(Pino_Beans)_Pt3', 'Frey_(Pino_Beans)_Pt4',
#        'Frey_(Pino_Beans)_Pt5', 'Frey_(Pino_Beans)_Pt6',
#        'Frey_(Pino_Beans)_Pt7', 'Frey_(Pino_Beans)_Pt8',
#        'Frey_(Pino_Beans)_Pt9', 'Frey_NE_Pt1', 'Frey_NE_Pt10',
#        'Frey_NE_Pt2', 'Frey_NE_Pt3', 'Frey_NE_Pt4', 'Frey_NE_Pt5',
#        'Frey_NE_Pt6', 'Frey_NE_Pt7', 'Frey_NE_Pt8', 'Frey_NE_Pt9',
#        'Frey_NW_Pt1', 'Frey_NW_Pt10', 'Frey_NW_Pt2', 'Frey_NW_Pt3',
#        'Frey_NW_Pt4', 'Frey_NW_Pt5', 'Frey_NW_Pt6', 'Frey_NW_Pt7',
#        'Frey_NW_Pt8', 'Frey_NW_Pt9', 'Frey_SE_Pt1', 'Frey_SE_Pt10',
#        'Frey_SE_Pt2', 'Frey_SE_Pt3', 'Frey_SE_Pt4', 'Frey_SE_Pt5',
#        'Frey_SE_Pt6', 'Frey_SE_Pt7', 'Frey_SE_Pt8', 'Frey_SE_Pt9',
#        'Frey_SW_Pt1', 'Frey_SW_Pt10', 'Frey_SW_Pt2', 'Frey_SW_Pt3',
#        'Frey_SW_Pt4', 'Frey_SW_Pt5', 'Frey_SW_Pt6', 'Frey_SW_Pt7',
#        'Frey_SW_Pt8', 'Frey_SW_Pt9', 'Half_Section_Pt1',
#        'Half_Section_Pt2', 'Half_Section_Pt3', 'Half_Section_Pt4',
#        'Half_Section_Pt5', 'Hogsback_Pt1', 'Hogsback_Pt10',
#        'Hogsback_Pt11', 'Hogsback_Pt12', 'Hogsback_Pt13', 'Hogsback_Pt14',
#        'Hogsback_Pt15', 'Hogsback_Pt16', 'Hogsback_Pt17', 'Hogsback_Pt18',
#        'Hogsback_Pt19', 'Hogsback_Pt2', 'Hogsback_Pt20', 'Hogsback_Pt21',
#        'Hogsback_Pt22', 'Hogsback_Pt23', 'Hogsback_Pt24', 'Hogsback_Pt25',
#        'Hogsback_Pt26', 'Hogsback_Pt27', 'Hogsback_Pt28', 'Hogsback_Pt29',
#        'Hogsback_Pt3', 'Hogsback_Pt30', 'Hogsback_Pt4', 'Hogsback_Pt5',
#        'Hogsback_Pt6', 'Hogsback_Pt7', 'Hogsback_Pt8', 'Hogsback_Pt9',
#        'Home_Pt1', 'Home_Pt10', 'Home_Pt11', 'Home_Pt12', 'Home_Pt13',
#        'Home_Pt14', 'Home_Pt15', 'Home_Pt16', 'Home_Pt17', 'Home_Pt18',
#        'Home_Pt19', 'Home_Pt2', 'Home_Pt20', 'Home_Pt21', 'Home_Pt22',
#        'Home_Pt23', 'Home_Pt24', 'Home_Pt25', 'Home_Pt26', 'Home_Pt27',
#        'Home_Pt28', 'Home_Pt29', 'Home_Pt3', 'Home_Pt30', 'Home_Pt31',
#        'Home_Pt32', 'Home_Pt33', 'Home_Pt34', 'Home_Pt35', 'Home_Pt36',
#        'Home_Pt37', 'Home_Pt38', 'Home_Pt4', 'Home_Pt5', 'Home_Pt6',
#        'Home_Pt7', 'Home_Pt8', 'Home_Pt9', 'Meadow_Pt1', 'Meadow_Pt10',
#        'Meadow_Pt11', 'Meadow_Pt12', 'Meadow_Pt13', 'Meadow_Pt2',
#        'Meadow_Pt3', 'Meadow_Pt4', 'Meadow_Pt5', 'Meadow_Pt6',
#        'Meadow_Pt7', 'Meadow_Pt8', 'Meadow_Pt9', 'Middle_Lake_Creek_Pt1',
#        'Middle_Lake_Creek_Pt10', 'Middle_Lake_Creek_Pt11',
#        'Middle_Lake_Creek_Pt12', 'Middle_Lake_Creek_Pt13',
#        'Middle_Lake_Creek_Pt14', 'Middle_Lake_Creek_Pt15',
#        'Middle_Lake_Creek_Pt16', 'Middle_Lake_Creek_Pt17',
#        'Middle_Lake_Creek_Pt18', 'Middle_Lake_Creek_Pt19',
#        'Middle_Lake_Creek_Pt2', 'Middle_Lake_Creek_Pt20',
#        'Middle_Lake_Creek_Pt21', 'Middle_Lake_Creek_Pt22',
#        'Middle_Lake_Creek_Pt23', 'Middle_Lake_Creek_Pt24',
#        'Middle_Lake_Creek_Pt25', 'Middle_Lake_Creek_Pt26',
#        'Middle_Lake_Creek_Pt27', 'Middle_Lake_Creek_Pt28',
#        'Middle_Lake_Creek_Pt29', 'Middle_Lake_Creek_Pt3',
#        'Middle_Lake_Creek_Pt30', 'Middle_Lake_Creek_Pt31',
#        'Middle_Lake_Creek_Pt32', 'Middle_Lake_Creek_Pt33',
#        'Middle_Lake_Creek_Pt34', 'Middle_Lake_Creek_Pt35',
#        'Middle_Lake_Creek_Pt36', 'Middle_Lake_Creek_Pt37',
#        'Middle_Lake_Creek_Pt38', 'Middle_Lake_Creek_Pt39',
#        'Middle_Lake_Creek_Pt4', 'Middle_Lake_Creek_Pt40',
#        'Middle_Lake_Creek_Pt41', 'Middle_Lake_Creek_Pt42',
#        'Middle_Lake_Creek_Pt43', 'Middle_Lake_Creek_Pt44',
#        'Middle_Lake_Creek_Pt45', 'Middle_Lake_Creek_Pt46',
#        'Middle_Lake_Creek_Pt47', 'Middle_Lake_Creek_Pt48',
#        'Middle_Lake_Creek_Pt49', 'Middle_Lake_Creek_Pt5',
#        'Middle_Lake_Creek_Pt50', 'Middle_Lake_Creek_Pt51',
#        'Middle_Lake_Creek_Pt52', 'Middle_Lake_Creek_Pt53',
#        'Middle_Lake_Creek_Pt54', 'Middle_Lake_Creek_Pt55',
#        'Middle_Lake_Creek_Pt56', 'Middle_Lake_Creek_Pt57',
#        'Middle_Lake_Creek_Pt58', 'Middle_Lake_Creek_Pt59',
#        'Middle_Lake_Creek_Pt6', 'Middle_Lake_Creek_Pt60',
#        'Middle_Lake_Creek_Pt61', 'Middle_Lake_Creek_Pt62',
#        'Middle_Lake_Creek_Pt63', 'Middle_Lake_Creek_Pt64',
#        'Middle_Lake_Creek_Pt65', 'Middle_Lake_Creek_Pt66',
#        'Middle_Lake_Creek_Pt67', 'Middle_Lake_Creek_Pt68',
#        'Middle_Lake_Creek_Pt69', 'Middle_Lake_Creek_Pt7',
#        'Middle_Lake_Creek_Pt70', 'Middle_Lake_Creek_Pt71',
#        'Middle_Lake_Creek_Pt72', 'Middle_Lake_Creek_Pt73',
#        'Middle_Lake_Creek_Pt74', 'Middle_Lake_Creek_Pt75',
#        'Middle_Lake_Creek_Pt76', 'Middle_Lake_Creek_Pt77',
#        'Middle_Lake_Creek_Pt78', 'Middle_Lake_Creek_Pt79',
#        'Middle_Lake_Creek_Pt8', 'Middle_Lake_Creek_Pt80',
#        'Middle_Lake_Creek_Pt81', 'Middle_Lake_Creek_Pt9',
#        'Miller_Place_Pt1', 'Miller_Place_Pt10', 'Miller_Place_Pt11',
#        'Miller_Place_Pt12', 'Miller_Place_Pt13', 'Miller_Place_Pt14',
#        'Miller_Place_Pt15', 'Miller_Place_Pt16', 'Miller_Place_Pt17',
#        'Miller_Place_Pt18', 'Miller_Place_Pt19', 'Miller_Place_Pt2',
#        'Miller_Place_Pt20', 'Miller_Place_Pt21', 'Miller_Place_Pt22',
#        'Miller_Place_Pt23', 'Miller_Place_Pt24', 'Miller_Place_Pt25',
#        'Miller_Place_Pt26', 'Miller_Place_Pt27', 'Miller_Place_Pt28',
#        'Miller_Place_Pt29', 'Miller_Place_Pt3', 'Miller_Place_Pt30',
#        'Miller_Place_Pt31', 'Miller_Place_Pt4', 'Miller_Place_Pt5',
#        'Miller_Place_Pt6', 'Miller_Place_Pt7', 'Miller_Place_Pt8',
#        'Miller_Place_Pt9', 'N_School_Section_Pt1',
#        'N_School_Section_Pt10', 'N_School_Section_Pt11',
#        'N_School_Section_Pt12', 'N_School_Section_Pt2',
#        'N_School_Section_Pt3', 'N_School_Section_Pt4',
#        'N_School_Section_Pt5', 'N_School_Section_Pt6',
#        'N_School_Section_Pt7', 'N_School_Section_Pt8',
#        'N_School_Section_Pt9', 'NoName_Nachtman_360_Pt1',
#        'NoName_Nachtman_360_Pt2', 'NoName_Nachtman_360_Pt3',
#        'NoName_Nachtman_360_Pt4', 'NoName_Nachtman_360_Pt5',
#        'NoName_Nacthman_634_Pt1', 'NoName_Nacthman_634_Pt10',
#        'NoName_Nacthman_634_Pt11', 'NoName_Nacthman_634_Pt12',
#        'NoName_Nacthman_634_Pt13', 'NoName_Nacthman_634_Pt14',
#        'NoName_Nacthman_634_Pt15', 'NoName_Nacthman_634_Pt16',
#        'NoName_Nacthman_634_Pt17', 'NoName_Nacthman_634_Pt18',
#        'NoName_Nacthman_634_Pt19', 'NoName_Nacthman_634_Pt2',
#        'NoName_Nacthman_634_Pt20', 'NoName_Nacthman_634_Pt21',
#        'NoName_Nacthman_634_Pt22', 'NoName_Nacthman_634_Pt23',
#        'NoName_Nacthman_634_Pt24', 'NoName_Nacthman_634_Pt25',
#        'NoName_Nacthman_634_Pt26', 'NoName_Nacthman_634_Pt27',
#        'NoName_Nacthman_634_Pt28', 'NoName_Nacthman_634_Pt29',
#        'NoName_Nacthman_634_Pt3', 'NoName_Nacthman_634_Pt30',
#        'NoName_Nacthman_634_Pt4', 'NoName_Nacthman_634_Pt5',
#        'NoName_Nacthman_634_Pt6', 'NoName_Nacthman_634_Pt7',
#        'NoName_Nacthman_634_Pt8', 'NoName_Nacthman_634_Pt9',
#        'North_Owens_Pt1', 'North_Owens_Pt10', 'North_Owens_Pt11',
#        'North_Owens_Pt12', 'North_Owens_Pt13', 'North_Owens_Pt2',
#        'North_Owens_Pt3', 'North_Owens_Pt4', 'North_Owens_Pt5',
#        'North_Owens_Pt6', 'North_Owens_Pt7', 'North_Owens_Pt8',
#        'North_Owens_Pt9', 'PastureNE_Weiss1', 'PastureNE_Weiss2',
#        'PastureNE_Weiss3', 'PastureNE_Weiss4', 'PastureNE_Weiss5',
#        'PastureNE_Weiss6', 'PastureNE_Weiss7', 'Pellatz_South_Pt1',
#        'Pellatz_South_Pt2', 'Pellatz_South_Pt3', 'Rattlesnake_Pt1',
#        'Rattlesnake_Pt10', 'Rattlesnake_Pt2', 'Rattlesnake_Pt3',
#        'Rattlesnake_Pt4', 'Rattlesnake_Pt5', 'Rattlesnake_Pt6',
#        'Rattlesnake_Pt7', 'Rattlesnake_Pt8', 'Rattlesnake_Pt9',
#        'S_School_Section_Pt1', 'S_School_Section_Pt10',
#        'S_School_Section_Pt11', 'S_School_Section_Pt12',
#        'S_School_Section_Pt13', 'S_School_Section_Pt14',
#        'S_School_Section_Pt15', 'S_School_Section_Pt16',
#        'S_School_Section_Pt17', 'S_School_Section_Pt18',
#        'S_School_Section_Pt19', 'S_School_Section_Pt2',
#        'S_School_Section_Pt3', 'S_School_Section_Pt4',
#        'S_School_Section_Pt5', 'S_School_Section_Pt6',
#        'S_School_Section_Pt7', 'S_School_Section_Pt8',
#        'S_School_Section_Pt9', 'Sawmill_Pt1', 'Sawmill_Pt2',
#        'Sawmill_Pt3', 'Sawmill_Pt4', 'Sawmill_Pt5', 'Sawmill_Pt6',
#        'Section_4_Pt1', 'Section_4_Pt10', 'Section_4_Pt11',
#        'Section_4_Pt12', 'Section_4_Pt13', 'Section_4_Pt2',
#        'Section_4_Pt3', 'Section_4_Pt4', 'Section_4_Pt5', 'Section_4_Pt6',
#        'Section_4_Pt7', 'Section_4_Pt8', 'Section_4_Pt9', 'Section_8_Pt1',
#        'Section_8_Pt2', 'Section_8_Pt3', 'Section_8_Pt4', 'Section_8_Pt5',
#        'Section_8_Pt6', 'Section_8_Pt7', 'Section_8_Pt8',
#        'South_Pasture_Pt1', 'South_Pasture_Pt2', 'South_Pasture_Pt3',
#        'South_Pasture_Pt4', 'South_Pasture_Pt5', 'South_Pasture_Pt6',
#        'South_Pasture_Pt7', 'Strips_Pt1', 'Strips_Pt2', 'Strips_Pt3',
#        'Top_Pt1', 'Top_Pt10', 'Top_Pt11', 'Top_Pt12', 'Top_Pt13',
#        'Top_Pt14', 'Top_Pt2', 'Top_Pt3', 'Top_Pt4', 'Top_Pt5', 'Top_Pt6',
#        'Top_Pt7', 'Top_Pt8', 'Top_Pt9', 'Upper_Rattlesnake_Pt1',
#        'Upper_Rattlesnake_Pt10', 'Upper_Rattlesnake_Pt11',
#        'Upper_Rattlesnake_Pt12', 'Upper_Rattlesnake_Pt13',
#        'Upper_Rattlesnake_Pt14', 'Upper_Rattlesnake_Pt15',
#        'Upper_Rattlesnake_Pt16', 'Upper_Rattlesnake_Pt17',
#        'Upper_Rattlesnake_Pt18', 'Upper_Rattlesnake_Pt19',
#        'Upper_Rattlesnake_Pt2', 'Upper_Rattlesnake_Pt20',
#        'Upper_Rattlesnake_Pt21', 'Upper_Rattlesnake_Pt22',
#        'Upper_Rattlesnake_Pt23', 'Upper_Rattlesnake_Pt24',
#        'Upper_Rattlesnake_Pt25', 'Upper_Rattlesnake_Pt26',
#        'Upper_Rattlesnake_Pt27', 'Upper_Rattlesnake_Pt28',
#        'Upper_Rattlesnake_Pt29', 'Upper_Rattlesnake_Pt3',
#        'Upper_Rattlesnake_Pt30', 'Upper_Rattlesnake_Pt31',
#        'Upper_Rattlesnake_Pt32', 'Upper_Rattlesnake_Pt33',
#        'Upper_Rattlesnake_Pt34', 'Upper_Rattlesnake_Pt35',
#        'Upper_Rattlesnake_Pt36', 'Upper_Rattlesnake_Pt37',
#        'Upper_Rattlesnake_Pt38', 'Upper_Rattlesnake_Pt39',
#        'Upper_Rattlesnake_Pt4', 'Upper_Rattlesnake_Pt40',
#        'Upper_Rattlesnake_Pt41', 'Upper_Rattlesnake_Pt42',
#        'Upper_Rattlesnake_Pt43', 'Upper_Rattlesnake_Pt44',
#        'Upper_Rattlesnake_Pt45', 'Upper_Rattlesnake_Pt5',
#        'Upper_Rattlesnake_Pt6', 'Upper_Rattlesnake_Pt7',
#        'Upper_Rattlesnake_Pt8', 'Upper_Rattlesnake_Pt9',
#        'West_Pasture_Pt1', 'West_Pasture_Pt2', 'West_Pasture_Pt3',
#        'West_Pasture_Pt4', 'West_Pasture_Pt5', 'West_Pasture_Pt6',
#        'West_Pasture_Pt7', 'West_Pasture_Pt8', 'West_Rattlesnake_Pt1',
#        'West_Rattlesnake_Pt10', 'West_Rattlesnake_Pt11',
#        'West_Rattlesnake_Pt12', 'West_Rattlesnake_Pt13',
#        'West_Rattlesnake_Pt14', 'West_Rattlesnake_Pt15',
#        'West_Rattlesnake_Pt16', 'West_Rattlesnake_Pt17',
#        'West_Rattlesnake_Pt18', 'West_Rattlesnake_Pt19',
#        'West_Rattlesnake_Pt2', 'West_Rattlesnake_Pt20',
#        'West_Rattlesnake_Pt21', 'West_Rattlesnake_Pt22',
#        'West_Rattlesnake_Pt23', 'West_Rattlesnake_Pt24',
#        'West_Rattlesnake_Pt25', 'West_Rattlesnake_Pt26',
#        'West_Rattlesnake_Pt27', 'West_Rattlesnake_Pt28',
#        'West_Rattlesnake_Pt29', 'West_Rattlesnake_Pt3',
#        'West_Rattlesnake_Pt30', 'West_Rattlesnake_Pt31',
#        'West_Rattlesnake_Pt32', 'West_Rattlesnake_Pt33',
#        'West_Rattlesnake_Pt34', 'West_Rattlesnake_Pt35',
#        'West_Rattlesnake_Pt36', 'West_Rattlesnake_Pt37',
#        'West_Rattlesnake_Pt38', 'West_Rattlesnake_Pt4',
#        'West_Rattlesnake_Pt5', 'West_Rattlesnake_Pt6',
#        'West_Rattlesnake_Pt7', 'West_Rattlesnake_Pt8',
#        'West_Rattlesnake_Pt9', 'West_Weiss_Pt1', 'West_Weiss_Pt10',
#        'West_Weiss_Pt11', 'West_Weiss_Pt12', 'West_Weiss_Pt13',
#        'West_Weiss_Pt14', 'West_Weiss_Pt15', 'West_Weiss_Pt16',
#        'West_Weiss_Pt17', 'West_Weiss_Pt18', 'West_Weiss_Pt19',
#        'West_Weiss_Pt2', 'West_Weiss_Pt20', 'West_Weiss_Pt21',
#        'West_Weiss_Pt22', 'West_Weiss_Pt23', 'West_Weiss_Pt24',
#        'West_Weiss_Pt25', 'West_Weiss_Pt26', 'West_Weiss_Pt27',
#        'West_Weiss_Pt28', 'West_Weiss_Pt29', 'West_Weiss_Pt3',
#        'West_Weiss_Pt30', 'West_Weiss_Pt31', 'West_Weiss_Pt32',
#        'West_Weiss_Pt33', 'West_Weiss_Pt4', 'West_Weiss_Pt5',
#        'West_Weiss_Pt6', 'West_Weiss_Pt7', 'West_Weiss_Pt8',
#        'West_Weiss_Pt9'], dtype=object)

# %%
gdf_out.to_file(os.path.join(baseDIR, '2021_Sampling/TB_wGain_sampling_2021_fixed_20220607.shp'))

# %%
os.path.basename(os.getcwd())
# Out:
# 'prep'

# %%
gdf_out.to_file(os.path.join(os.path.dirname(os.getcwd()),
                             'data/shps/TB_wGain_sampling_2021_fixed_20220607.shp'))
