# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# Import ANPP file

# %%
anpp= pd.read_csv('GMDR_ANPP_13Dec21.csv')

# %%
anpp.head()
# Out:
#                                    Collected by Sorted by Weighed by  \
# 0  Jill, Carley, Joseph, Spencer, Julia, Claire      Jill       Jill
# 1  Jill, Carley, Joseph, Spencer, Julia, Claire      Jill       Jill
# 2  Jill, Carley, Joseph, Spencer, Julia, Claire      Jill       Jill
# 3  Jill, Carley, Joseph, Spencer, Julia, Claire      Jill       Jill
# 4  Jill, Carley, Joseph, Spencer, Julia, Claire      Jill       Jill
#
#          Date  Year Site  Block  Paddock  Drought Grazing  ... C4P(kg/ha)  \
# 0  July, 2019  2019   TB      1        2       75   HHMMM  ...        0.0
# 1  July, 2019  2019   TB      1        2       75   HHMMM  ...       26.0
# 2  July, 2019  2019   TB      1        2       99   HHMMM  ...        0.0
# 3  July, 2019  2019   TB      1        2       99   HHMMM  ...        0.0
# 4  July, 2019  2019   TB      1        2        1   HHMMM  ...      360.0
#
#    Forb(kg/ha)  StandingDead(kg/ha)  AnnualGrass(kg/ha) Vulpia(kg/ha)  \
# 0        400.0                290.0               #REF!           6.0
# 1        200.0               1060.0               #REF!          36.0
# 2        580.0                340.0               #REF!          22.0
# 3        380.0                320.0               #REF!           8.0
# 4        110.0                140.0               #REF!          62.0
#
#    Bromus(kg/ha)  GUSA(g/m2).1 Litter(kg/ha)  cover of arfr  \
# 0         1052.0           0.0        -200.0            NaN
# 1         1520.0           0.0        -200.0            NaN
# 2           40.0           0.0        -200.0            NaN
# 3           20.0           0.0        -200.0            NaN
# 4           16.0           0.0        -200.0            NaN
#
#                                  REWEIGH
# 0                            Bromus 5.26
# 1  Vulpia 0.17, Bromus 7.57, Litter 5.34
# 2                              Forb 2.93
# 3                                    NaN
# 4                            Vulpia 0.30
#
# [5 rows x 72 columns]

# %% [markdown]
# Create a list of the columns from original file to work with

# %%
cols=['Date', 'Year', 'Drought', 'Grazing', 'PlotID', 'C3P(g)', 'C4P(g)', 
      'Forb(g)','Standing Dead(g)', 'Vulpia(g)', 'Bromus(g)']

# %%
anpp=anpp[cols]

# %% [markdown]
# Create a list of columns (biomass categories) to be added together

# %%
plants=['C3P(g)', 'C4P(g)', 'Forb(g)','Standing Dead(g)', 'Vulpia(g)', 'Bromus(g)']

# %%
plants
# Out:
# ['C3P(g)', 'C4P(g)', 'Forb(g)', 'Standing Dead(g)', 'Vulpia(g)', 'Bromus(g)']

# %%
anpp.head()
# Out:
#          Date  Year  Drought Grazing PlotID  C3P(g)  C4P(g)  Forb(g)  \
# 0  July, 2019  2019       75   HHMMM      1    0.50    0.00     2.00
# 1  July, 2019  2019       75   HHMMM      1    2.45    0.13     1.00
# 2  July, 2019  2019       99   HHMMM      2    2.25    0.00     2.90
# 3  July, 2019  2019       99   HHMMM      2    6.00    0.00     1.90
# 4  July, 2019  2019        1   HHMMM      3    0.85    1.80     0.55
#
#    Standing Dead(g) Vulpia(g) Bromus(g)
# 0              1.45      0.03      5.26
# 1              5.30      0.18       7.6
# 2              1.70      0.11       0.2
# 3              1.60      0.04       0.1
# 4              0.70      0.31      0.08

# %%
anpp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              324 non-null    object
#  1   Year              432 non-null    int64
#  2   Drought           432 non-null    int64
#  3   Grazing           432 non-null    object
#  4   PlotID            432 non-null    object
#  5   C3P(g)            430 non-null    float64
#  6   C4P(g)            430 non-null    float64
#  7   Forb(g)           430 non-null    float64
#  8   Standing Dead(g)  430 non-null    float64
#  9   Vulpia(g)         430 non-null    object
#  10  Bromus(g)         430 non-null    object
# dtypes: float64(4), int64(2), object(5)
# memory usage: 37.2+ KB

# %%
anpp['Bromus(g)'].sort_values(ascending=False)
# Out:
# 305      0
# 306      0
# 431      0
# 146    NaN
# 158    NaN
# Name: Bromus(g), dtype: object

# %%
anpp['Vulpia(g)'].sort_values(ascending=False)
# Out:
# 247    1.13
# 182    0.90
# 154    0.70
# 226    0.43
# 155    0.40
#        ...
# 34     0.00
# 33     0.00
# 431    0.00
# 146     NaN
# 158     NaN
# Name: Vulpia(g), Length: 432, dtype: float64

# %% [markdown]
# Clean up Vulpia and Bromus and convert to floats

# %%
anpp['Vulpia(g)'].replace('?','0', inplace=True)

# %%
anpp['Vulpia(g)'].replace('','0', inplace=True)

# %%
anpp['Vulpia(g)']=anpp['Vulpia(g)'].astype('float64')

# %%
anpp['Bromus(g)'].replace('?','0', inplace=True)

# %%
anpp['Bromus(g)'].replace('','0', inplace=True)

# %%
anpp['Bromus(g)']=anpp['Vulpia(g)'].astype('float64')

# %% [markdown]
# Sum biomass categories to create new column

# %%
anpp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              324 non-null    object
#  1   Year              432 non-null    int64
#  2   Drought           432 non-null    int64
#  3   Grazing           432 non-null    object
#  4   PlotID            432 non-null    object
#  5   C3P(g)            430 non-null    float64
#  6   C4P(g)            430 non-null    float64
#  7   Forb(g)           430 non-null    float64
#  8   Standing Dead(g)  430 non-null    float64
#  9   Vulpia(g)         430 non-null    float64
#  10  Bromus(g)         430 non-null    float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 37.2+ KB

# %%
anpp['total']= anpp[plants].sum(axis=1) #   df['Sum'] = df[col_list].sum(axis=1)

# %%
anpp.head()
# Out:
#          Date  Year  Drought Grazing PlotID  C3P(g)  C4P(g)  Forb(g)  \
# 0  July, 2019  2019       75   HHMMM      1    0.50    0.00     2.00
# 1  July, 2019  2019       75   HHMMM      1    2.45    0.13     1.00
# 2  July, 2019  2019       99   HHMMM      2    2.25    0.00     2.90
# 3  July, 2019  2019       99   HHMMM      2    6.00    0.00     1.90
# 4  July, 2019  2019        1   HHMMM      3    0.85    1.80     0.55
#
#    Standing Dead(g)  Vulpia(g)  Bromus(g)  total
# 0              1.45       0.03       0.03   4.01
# 1              5.30       0.18       0.18   9.24
# 2              1.70       0.11       0.11   7.07
# 3              1.60       0.04       0.04   9.58
# 4              0.70       0.31       0.31   4.52

# %%
anpp['g/m2']=anpp.total/0.05

# %%
anpp.head()
# Out:
#          Date  Year  Drought Grazing PlotID  C3P(g)  C4P(g)  Forb(g)  \
# 0  July, 2019  2019       75   HHMMM      1    0.50    0.00     2.00
# 1  July, 2019  2019       75   HHMMM      1    2.45    0.13     1.00
# 2  July, 2019  2019       99   HHMMM      2    2.25    0.00     2.90
# 3  July, 2019  2019       99   HHMMM      2    6.00    0.00     1.90
# 4  July, 2019  2019        1   HHMMM      3    0.85    1.80     0.55
#
#    Standing Dead(g)  Vulpia(g)  Bromus(g)  total   g/m2
# 0              1.45       0.03       0.03   4.01   80.2
# 1              5.30       0.18       0.18   9.24  184.8
# 2              1.70       0.11       0.11   7.07  141.4
# 3              1.60       0.04       0.04   9.58  191.6
# 4              0.70       0.31       0.31   4.52   90.4
